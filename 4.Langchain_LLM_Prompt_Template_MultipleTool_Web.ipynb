# %%
import os
from dotenv import load_dotenv

from langchain_core.prompts import PromptTemplate
from langchain_classic.chains.llm import LLMChain
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import Tool
from langchain_community.tools import TavilySearchResults

# 🔐 Load API key from .env file
load_dotenv()
tavily_api_key = os.getenv("")
google_api_key = os.getenv("")

# ⚡ Initialize the LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash",   # You can change to gemini-1.5-pro, etc.
    temperature=0,
    google_api_key=""
)



# ✅ Tool 1: Simple QA
qa_prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = LLMChain(llm=llm, prompt=qa_prompt)
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.run,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer
summary_prompt = PromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = LLMChain(llm=llm, prompt=summary_prompt)
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.run,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)
search_tool = Tool(
    name="Web Search",
    func=TavilySearchResults(max_results=3).run,
    description="Search the internet for current information"
)

# 🧪 Run each tool manually
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain. 
It uses graph-based design to model agent workflows and memory.
"""
search_query = "Latest updates on gemini 3.5 flash google"

print("\n🧠 Simple QA Tool Output:\n", qa_tool.run({"question": qa_query}))
print("\n📝 Summarizer Tool Output:\n", summary_tool.run({"text": summary_text}))
print("\n🌐 Web Search Tool Output:\n", search_tool.run(search_query))
# Out:
# 🧠 Simple QA Tool Output:
#  **LangGraph** is an extension of LangChain designed for building **stateful, multi-actor applications with LLMs (Large Language Models)**.
#
# In simple terms, it is a framework that allows you to build complex AI agents using a **graph-based structure** (nodes and edges).
#
# Here is a clear breakdown of what it is, why it matters, and how it works:
#
# ---
#
# ### 1. Why do we need LangGraph? (The Problem it Solves)
# Standard LangChain is great for **linear** workflows (e.g., *Prompt $\rightarrow$ LLM $\rightarrow$ Output*).
#
# However, real-world AI agents rarely work in a straight line. They need to:
# *   **Loop:** Try a task, check the result, and if it’s wrong, try again (a feedback loop).
# *   **Collaborate:** Have multiple specialized agents talk to each other (e.g., a Writer Agent and an Editor Agent).
#
# Standard LangChain struggles with these loops. **LangGraph was created specifically to allow loops (cycles) in LLM workflows.**
#
# ---
#
# ### 2. Core Concepts of LangGraph
# LangGraph models your AI application as a **graph** consisting of three main elements:
#
# 1.  **State:** The shared memory of your application. Every step in the graph can read from and write to this state (e.g., keeping track of the conversation history or retrieved documents).
# 2.  **Nodes:** The steps or actions in your workflow. A node can be an LLM call, a Python function, or a database query.
# 3.  **Edges:** The connections between nodes. Edges define the flow of the application. They can be **conditional** (e.g., *"If the LLM output is 'yes', go to Node A; if 'no', go to Node B"*).
#
# ---
#
# ### 3. Key Features
# *   **Cycles and Loops:** Easily create agent workflows that can self-correct, iterate, and loop until a goal is met.
# *   **Persistence (Memory):** It automatically saves the state of the graph after every step. This allows for easy "time-travel" (rewinding the agent's steps) and error recovery.
# *   **Human-in-the-loop:** You can pause the graph to wait for human approval or input (e.g., "Do you approve this API call?") and then resume it.
#
# ---
#
# ### A Simple Analogy
# *   **Standard LangChain** is like a **conveyor belt**. Raw materials go in one end, steps are performed in a strict order, and a finished product comes out the other end.
# *   **LangGraph** is like a **flowchart with decision loops**. You can go from Step A to Step B, but if Step B fails, the flowchart tells you to loop back to Step A and try again.
#
# 📝 Summarizer Tool Output:
#  **Summary:**
#
# LangGraph is a framework built on LangChain that uses graph-based design to model workflows and memory for stateful, multi-step agents.
#
# 🌐 Web Search Tool Output:
#  [{'title': 'Release notes | Gemini API - Google AI for Developers', 'url': 'https://ai.google.dev/gemini-api/docs/changelog', 'content': "## July 21, 2026\n\n   Gemini 3.6 Flash and Gemini 3.5 Flash-Lite generally available (GA): Released stable, production-ready versions of our latest 3.x Flash models:\n\n       Gemini 3.6 Flash (`gemini-3.6-flash`): Features improved token efficiency and code/agentic planning capabilities at a lower price point than 3.5 Flash, resolving developer feedback around output verbosity.\n       Gemini 3.5 Flash-Lite (`gemini-3.5-flash-lite`): Offers a low-latency, highly cost-effective subagent option designed for high-volume automation.\n\nTo learn more, see the Latest Gemini model guide.\n\n   Deprecated parameters: The sampling parameters `temperature`, `top_p` and `top_k` are now deprecated. See the Latest Gemini Model for details.\n\n## July 6, 2026 [...] ## September 19, 2024\n\nAI Studio updates:\n\n   Added thumb-up and thumb-down buttons to model responses, to enable users to provide feedback on the quality of a response.\n\nAPI updates:\n\n   Added support for Google Cloud credits, which can now be used towards Gemini API usage.\n\n## September 17, 2024\n\nAI Studio updates:\n\n   Added an Open in Colab button that exports a prompt – and the code to run it – to a Colab notebook. The feature doesn't yet support prompting with tools (JSON mode, function calling, or code execution).\n\n## September 13, 2024\n\nAI Studio updates:\n\n   Added support for compare mode, which lets you compare responses across models and prompts to find the best fit for your use case.\n\n## August 30, 2024\n\nModel updates: [...] ## May 20, 2025\n\nAPI updates:\n\n   Launched support for custom video preprocessing using clipping intervals and configurable frame rate sampling.\n   Launched multi-tool use, which supports configuring code execution and Grounding with Google Search on the same `generateContent` request.\n   Launched support for asynchronous function calls in the Live API.\n   Launched an experimental URL context tool for providing URLs as additional context to prompts.\n\nModel updates:", 'score': 0.8437023}, {'title': 'Gemini 3.5: frontier intelligence with action - Google Blog', 'url': 'https://blog.google/innovation-and-ai/models-and-research/gemini-models/gemini-3-5', 'content': '## 3.5 Flash is available today\n\nGemini 3.5 Flash is generally available via Google Antigravity, the Gemini API in Google AI Studio and Android Studio, Gemini Enterprise Agent Platform and Gemini Enterprise. It’s also now available to everyone in the Gemini app and AI Mode in Search. On behalf of the entire Gemini team, we can’t wait to see what you build.\n\nCollection\n\n## I/O 2026\n\nThe image shows a colorful abstract design with the Google I/O 2026 logo.\n\n## Get the latest news from Google in your inbox\n\nSign up for our newsletters with product updates, event information, special offers, and more.\n\nDone. Just one step more.\n\nCheck your inbox to confirm your subscription.\n\nYou can also subscribe with a different email address. [...] When coupled with the updated Antigravity harness, 3.5 Flash becomes a powerful engine for deploying collaborative subagents to tackle problems at scale for the most demanding use cases. Under supervision, it can reliably execute multi-step workflows and coding tasks while sustaining frontier performance.\n\nPowered by Antigravity, 3.5 Flash executes multi-step workflows to automatically rename and categorize unstructured assets based on dynamic criteria.\n\nLeveraging Antigravity, 3.5 Flash uses two agents to synthesize the AlphaZero paper and code a fully playable game in six hours.\n\n3.5 Flash uses the Antigravity harness to transform a messy legacy codebase to Next.js.\n\n3.5 Flash uses subagents to create new city landscapes in Antigravity.', 'score': 0.81595254}, {'title': '🔥 App Update: Gemini 3.5 Flash in Make - News - Make Community', 'url': 'https://community.make ...
